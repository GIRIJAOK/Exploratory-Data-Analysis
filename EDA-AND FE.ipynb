# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv(r'G:\New folder\desktop\code\EDA\student.csv')

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data['gender'].dtypes
# Out:
# dtype('O')

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
[fea for fea in data.columns] #Get a list of column names
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
cat_data=[fea for fea in data.columns if data[fea].dtype == 'O']

# %%
cat_data
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
num_col=[fea for fea in data.columns if data[fea].dtype != 'O']

# %%
num_col
# Out:
# ['math score', 'reading score', 'writing score']

# %%
data.memory_usage()
# Out:
# Index                           128
# gender                         8000
# race/ethnicity                 8000
# parental level of education    8000
# lunch                          8000
# test preparation course        8000
# math score                     8000
# reading score                  8000
# writing score                  8000
# dtype: int64

# %%
data.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
data.isnull().sum() #cheching missing values
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.duplicated() #cheching duplicate values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.nunique()  #checking unique values
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
data['gender'].unique() #checking unique values in a column
# Out:
# array(['female', 'male'], dtype=object)

# %%
data.describe() # statstics of data
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.describe().T
# Out:
#                 count    mean        std   min    25%   50%   75%    max
# math score     1000.0  66.089  15.163080   0.0  57.00  66.0  77.0  100.0
# reading score  1000.0  69.169  14.600192  17.0  59.00  70.0  79.0  100.0
# writing score  1000.0  68.054  15.195657  10.0  57.75  69.0  79.0  100.0

# %%
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
data.cov()
# Out:
#                math score  reading score  writing score
# math score     229.918998     180.998958     184.939133
# reading score  180.998958     213.165605     211.786661
# writing score  184.939133     211.786661     230.907992

# %%
data.skew()
# Out:
# math score      -0.278935
# reading score   -0.259105
# writing score   -0.289444
# dtype: float64

# %%
# Step 4: Visualizations

# 1. Histograms for each numerical feature
plt.figure(figsize=(20, 10))
data.hist(bins=20, edgecolor='black')
plt.suptitle("Histograms Plot", fontsize=16)
plt.show()

# %%
# Create a figure for boxplots
plt.figure(figsize=(14, 10))

# Boxplot for Math Scores by Gender

data.boxplot(column='math score', by='gender')
plt.title('Math Scores by Gender')
plt.suptitle('')  # Suppress the default title
plt.ylabel('Math Score')
# Out:
# Text(0, 0.5, 'Math Score')

# %%
# Boxplot for Reading Scores by Gender
data.boxplot(column='reading score', by='gender')
plt.title('Reading Scores by Gender')
plt.suptitle('')  # Suppress the default title
plt.ylabel('Reading Score')
# Out:
# Text(0, 0.5, 'Reading Score')

# %%
print(data.dtypes)
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
# Set up the figure
plt.figure(figsize=(14, 8))

# Boxplot for Math Scores by Gender

data.boxplot(column='math score', by='gender', grid=False, 
              boxprops=dict(color='red'), 
              whiskerprops=dict(color='blue'), 
              capprops=dict(color='blue'), 
              medianprops=dict(color='green'))
plt.title('Math Scores by Gender', fontsize=16)
plt.suptitle('')
plt.xlabel('Gender')
plt.ylabel('Math Score')
# Out:
# Text(0, 0.5, 'Math Score')

# %%
# Boxplot for Reading Scores by Race/Ethnicity
data.boxplot(column='reading score', by='race/ethnicity', grid=False, 
              boxprops=dict(color='black'), 
              whiskerprops=dict(color='black'), 
              capprops=dict(color='black'), 
              medianprops=dict(color='orange'))
plt.title('Reading Scores by Race/Ethnicity', fontsize=16)
plt.suptitle('')
plt.xlabel('Race/Ethnicity')
plt.ylabel('Reading Score')
# Out:
# Text(0, 0.5, 'Reading Score')

# %%
# Boxplot for Writing Scores by Parental Level of Education
data.boxplot(column='writing score', by='parental level of education', grid=False, 
              boxprops=dict(color='green'), 
              whiskerprops=dict(color='blue'), 
              capprops=dict(color='blue'), 
              medianprops=dict(color='red'))
plt.title('Writing Scores by Parental Level of Education', fontsize=16)
plt.suptitle('')
plt.xlabel('Parental Level of Education')
plt.ylabel('Writing Score')
plt.xticks(rotation=45)
# Out:
# (array([1, 2, 3, 4, 5, 6]),
#  [Text(1, 0, "associate's degree"),
#   Text(2, 0, "bachelor's degree"),
#   Text(3, 0, 'high school'),
#   Text(4, 0, "master's degree"),
#   Text(5, 0, 'some college'),
#   Text(6, 0, 'some high school')])

# %%
sns.distplot(data['math score'])  # left skewd
# Out:
# <AxesSubplot:xlabel='math score', ylabel='Density'>

# %%
sns.set(style="whitegrid")

# Create a boxplot for 'math score' by 'gender'
plt.figure(figsize=(12, 6))
sns.boxplot(x='gender', y='math score', data=data)
plt.title('Boxplot of Math Scores by Gender')
plt.xlabel('Gender')
plt.ylabel('Math Score')
plt.show()

# %%
# Set the aesthetics for the plots
sns.set(style="whitegrid")

# %%
# Scatter plot for Math vs. Reading Scores, colored by Gender
plt.figure(figsize=(10, 6))
sns.scatterplot(x='math score', y='reading score', hue='gender', data=data, style='gender', s=100)
plt.title('Scatter Plot of Math Scores vs. Reading Scores')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.legend(title='Gender')
plt.show()

# %%
# Scatter plot for Reading vs. Writing Scores, colored by Race/Ethnicity
plt.figure(figsize=(10, 6))
sns.scatterplot(x='reading score', y='writing score', hue='race/ethnicity', data=data, style='race/ethnicity', s=100)
plt.title('Scatter Plot of Reading Scores vs. Writing Scores')
plt.xlabel('Reading Score')
plt.ylabel('Writing Score')
plt.legend(title='Race/Ethnicity')
plt.show()

# %%
# Scatter plot for Math vs. Writing Scores, colored by Lunch Type
plt.figure(figsize=(10, 6))
sns.scatterplot(x='math score', y='writing score', hue='lunch', data=data, style='lunch', s=100)
plt.title('Scatter Plot of Math Scores vs. Writing Scores')
plt.xlabel('Math Score')
plt.ylabel('Writing Score')
plt.legend(title='Lunch Type')
plt.show()

# %%
# Scatter plot for Writing vs. Math Scores, colored by Test Preparation Course
plt.figure(figsize=(10, 6))
sns.scatterplot(x='writing score', y='math score', hue='test preparation course', data=data, style='test preparation course', s=100)
plt.title('Scatter Plot of Writing Scores vs. Math Scores')
plt.xlabel('Writing Score')
plt.ylabel('Math Score')
plt.legend(title='Test Preparation Course')
plt.show()

# %%
sns.distplot(data['reading score'])
# Out:
# <AxesSubplot:xlabel='reading score', ylabel='Density'>

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data['math score']+data['reading score']+data['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
data['average']=(data['math score']+data['reading score']+data['writing score'])/3

# %%
data['average']
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: average, Length: 1000, dtype: float64

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score    average
# 0                    none          72             72             74  72.666667
# 1               completed          69             90             88  82.333333
# 2                    none          90             95             93  92.666667
# 3                    none          47             57             44  49.333333
# 4                    none          76             78             75  76.333333

# %%
data.groupby('gender').count()
# Out:
#         race/ethnicity  parental level of education  lunch  \
# gender
# female             518                          518    518
# male               482                          482    482
#
#         test preparation course  math score  reading score  writing score  \
# gender
# female                      518         518            518            518
# male                        482         482            482            482
#
#         average
# gender
# female      518
# male        482

# %%
data.groupby('gender')

# %%
data.groupby('gender').mean()
# Out:
#         math score  reading score  writing score    average
# gender
# female   63.633205      72.608108      72.467181  69.569498
# male     68.728216      65.473029      63.311203  65.837483

# %%
data[data['math score']>30] #diplay the students have math score >30
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
data[data['math score']>30].count()
# Out:
# gender                         984
# race/ethnicity                 984
# parental level of education    984
# lunch                          984
# test preparation course        984
# math score                     984
# reading score                  984
# writing score                  984
# average                        984
# dtype: int64

# %%
data[data['math score']<30]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 91     male        group C                 high school  free/reduced
# 145  female        group C                some college  free/reduced
# 327    male        group A                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 363  female        group D            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 528  female        group D           bachelor's degree  free/reduced
# 601  female        group C                 high school      standard
# 683  female        group C            some high school  free/reduced
# 787  female        group B                some college      standard
# 842  female        group B                 high school  free/reduced
# ...

# %%
data[data['math score']<30].count()
# Out:
# gender                         14
# race/ethnicity                 14
# parental level of education    14
# lunch                          14
# test preparation course        14
# math score                     14
# reading score                  14
# writing score                  14
# average                        14
# dtype: int64

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'average'],
#       dtype='object')

# %%
data[num_col]
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
datanum=data[num_col]

# %%
datanum
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
datanum.head()
# Out:
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
from scipy.stats import normaltest

# %%
normaltest(datanum['math score'])
# Out:
# NormaltestResult(statistic=15.408960513931822, pvalue=0.00045080293869937836)

# %%
normaltest(datanum['math score'])[1]
# Out:
# 0.00045080293869937836

# %%
normaltest(datanum['math score'])[1]*100
# Out:
# 0.04508029386993784

# %%
sns.boxplot(data=data['math score'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data['reading score'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=data['writing score'])
# Out:
# <AxesSubplot:>

# %%
q1 = data['math score'].quantile(0.25)

# %%
q3 = data['math score'].quantile(0.75)

# %%
IQR = q3 - q1

# %%
upper_limit = q3 + (1.5 * IQR)

# %%
lower_limit = q1 - (1.5 * IQR)

# %%
upper_limit
# Out:
# 107.0

# %%
lower_limit
# Out:
# 27.0

# %%
data[data['math score']<lower_limit]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 17   female        group B            some high school  free/reduced
# 59   female        group C            some high school  free/reduced
# 145  female        group C                some college  free/reduced
# 338  female        group B            some high school  free/reduced
# 466  female        group D          associate's degree  free/reduced
# 787  female        group B                some college      standard
# 842  female        group B                 high school  free/reduced
# 980  female        group B                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 17                     none          18             32             28
# 59                     none           0             17             10
# 145                    none          22             39             33
# ...

# %%
data[data['math score']>upper_limit]
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score, average]
# Index: []

# %%
data['math score'].quantile(1.00)
# Out:
# 100.0

# %%
data['math score'].min()
# Out:
# 0

# %%
data['math score'].max()
# Out:
# 100

# %%
data['math score'].unique()
# Out:
# array([ 72,  69,  90,  47,  76,  71,  88,  40,  64,  38,  58,  65,  78,
#         50,  18,  46,  54,  66,  44,  74,  73,  67,  70,  62,  63,  56,
#         97,  81,  75,  57,  55,  53,  59,  82,  77,  33,  52,   0,  79,
#         39,  45,  60,  61,  41,  49,  30,  80,  42,  27,  43,  68,  85,
#         98,  87,  51,  99,  84,  91,  83,  89,  22, 100,  96,  94,  48,
#         35,  34,  86,  92,  37,  28,  24,  26,  95,  36,  29,  32,  93,
#         19,  23,   8], dtype=int64)

# %%
def outlier_threshold(data,variable):
    q1 = data[variable].quantile(0.25)
    q2 = data[variable].quantile(0.75)
    iqr = q2 - q1
    up_limit = q2 + (1.5*iqr)
    low_limit = q1 - (1.5*iqr)
    return up_limit, low_limit

# %%
outlier_threshold(data,variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-8f0e18992eea> in <module>
# ----> 1 outlier_threshold(data,variable)
#
# NameError: name 'variable' is not defined

# %%
sns.displot(datanum['math score'])

# %%
sns.boxplot(data=data['math score'])
# Out:
# <AxesSubplot:>

# %%
def find_outliers_IQR(data):
    q1=data.quantile(0.25)

    q3=data.quantile(0.75)

    IQR=q3-q1

    outliers = data[((data<(q1-1.5*IQR)) | (data>(q3+1.5*IQR)))]

    return outliers

# %%
find_outliers_IQR(data)
# Out:
#     gender race/ethnicity parental level of education lunch  \
# 0      NaN            NaN                         NaN   NaN
# 1      NaN            NaN                         NaN   NaN
# 2      NaN            NaN                         NaN   NaN
# 3      NaN            NaN                         NaN   NaN
# 4      NaN            NaN                         NaN   NaN
# ..     ...            ...                         ...   ...
# 995    NaN            NaN                         NaN   NaN
# 996    NaN            NaN                         NaN   NaN
# 997    NaN            NaN                         NaN   NaN
# 998    NaN            NaN                         NaN   NaN
# 999    NaN            NaN                         NaN   NaN
#
#     test preparation course  math score  reading score  writing score  average
# 0                       NaN         NaN            NaN            NaN      NaN
# 1                       NaN         NaN            NaN            NaN      NaN
# ...

# %%
def outlier_threshold(data,variable):
    q1=data[variable].quantile(0.25)
    q2=data[variable].quantile(0.75)
    iqr=q2-q1
    up_limit=q2+(1.5*iqr)
    lower_limit=q1-(1.5*iqr)
    return lower_limit,up_limit

# %% [markdown]
# # GRAPH ANALYSIS

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sns.countplot(data['gender'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(data['race/ethnicity'])
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='count'>

# %%
df=data.groupby('gender').mean()

# %%
df
# Out:
#         math score  reading score  writing score     average
# gender
# female   63.633205      72.608108      72.467181  160.397040
# male     68.728216      65.473029      63.311203  155.304979

# %%
df['average']
# Out:
# gender
# female    160.397040
# male      155.304979
# Name: average, dtype: float64

# %%
df['average'][0]
# Out:
# 160.3970398970399

# %%
df['average'][1]
# Out:
# 155.30497925311195

# %%
df['math score'][0]
# Out:
# 63.633204633204635

# %%
plt.figure(figsize=(10,10))
X=['Total avg','math avg']
female_score=df['average'][0],df['math score'][0]
male_score=df['average'][1],df['math score'][1]
X_axis=np.arange(len(X))
plt.bar(X_axis-0.2,male_score,0.4,label='male')
plt.bar(X_axis+0.2,female_score,0.4,label='female')

plt.xticks(X_axis,X)
plt.ylabel("marks")
plt.title("total avg vs math avg",fontweight='bold')
plt.legend()
plt.show()

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(datanum)

# %%
sns.heatmap(df.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title("corr between variable",color='black',size=15)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig = plt.gcf()
fig.set_size_inches(15,10)
plt.title("corr between variable",color='black',size=25)
plt.show()

# %%
sns.heatmap(datanum.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig = plt.gcf()
fig.set_size_inches(15,10)
plt.title("corr between variable",color='black',size=25)
plt.show()

# %%
sns.violinplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(data=datanum)
# Out:
# <AxesSubplot:>
